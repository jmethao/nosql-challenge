')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': '1',
#  '_id': ObjectId('677c907fee4bdbb6eecb5480')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': '1',
#  '_id': ObjectId('677c907fee4bdbb6eecb5481')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': '1',
#  '_id': ObjectId('677c907fee4bdbb6eecb5487')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': '1',
#  '_id': ObjectId('677c907fee4bdbb6eecb5488')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': '1',
#  '_id': ObjectId('677c907fee4bdbb6eecb548a')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': '1',
#  '_id': ObjectId('677c907fee4bdbb6eecb548b')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': '1',
#  '_id': ObjectId('677c907fee4bdbb6eecb548c')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': '1',
#  '_id': ObjectId('677c907fee4bdbb6eecb548d')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': '1',
#  '_id': ObjectId('677c907fee4bdbb6eecb5492')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': '1',
#  '_id': ObjectId('677c907fee4bdbb6eecb5493')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': '1',
#  '_id': ObjectId('677c907fee4bdbb6eecb5497')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': '1',
#  '_id': ObjectId('677c907fee4bdbb6eecb5499')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': '1',
#  '_id': ObjectId('677c907fee4bdbb6eecb549a')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': '1',
#  '_id': ObjectId('677c907fee4bdbb6eecb549b')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': '1',
#  '_id': ObjectId('677c907fee4bdbb6eecb549c')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': '1',
#  '_id': ObjectId('677c907fee4bdbb6eecb549d')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': '1',
#  '_id': ObjectId('677c907fee4bdbb6eecb549e')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': '1',
#  '_id': ObjectId('677c907fee4bdbb6eecb54a2')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': '1',
#  '_id': ObjectId('677c907fee4bdbb6eecb54a7')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': '1',
#  '_id': ObjectId('677c907fee4bdbb6eecb54a8')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': '1',
#  '_id': ObjectId('677c907fee4bdbb6eecb54a9')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': '1',
#  '_id': ObjectId('677c907fee4bdbb6eecb54ab')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': '1',
#  '_id': ObjectId('677c907fee4bdbb6eecb54ad')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': '1',
#  '_id': ObjectId('677c907fee4bdbb6eecb54b0')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': '1',
#  '_id': ObjectId('677c907fee4bdbb6eecb54b5')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': '1',
#  '_id': ObjectId('677c907fee4bdbb6eecb54bb')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': '1',
#  '_id': ObjectId('677c907fee4bdbb6eecb54bf')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': '1',
#  '_id': ObjectId('677c907fee4bdbb6eecb54c1')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': '1',
#  '_id': ObjectId('677c907fee4bdbb6eecb54c4')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': '1',
#  '_id': ObjectId('677c907fee4bdbb6eecb54c9')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': '1',
#  '_id': ObjectId('677c907fee4bdbb6eecb54ce')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': '1',
#  '_id': ObjectId('677c907fee4bdbb6eecb54d1')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': '1',
#  '_id': ObjectId('677c907fee4bdbb6eecb54d9')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': '1',
#  '_id': ObjectId('677c907fee4bdbb6eecb54da')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': '1',
#  '_id': ObjectId('677c907fee4bdbb6eecb54dc')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': '1',
#  '_id': ObjectId('677c907fee4bdbb6eecb54e1')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': '1',
#  '_id': ObjectId('677c907fee4bdbb6eecb5506')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': '1',
#  '_id': ObjectId('677c907fee4bdbb6eecb550d')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': '1',
#  '_id': ObjectId('677c907fee4bdbb6eecb5511')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': '1',
#  '_id': ObjectId('677c907fee4bdbb6eecb5515')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': '1',
#  '_id': ObjectId('677c907fee4bdbb6eecb5517')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': '1',
#  '_id': ObjectId('677c907fee4bdbb6eecb5518')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': '1',
#  '_id': ObjectId('677c907fee4bdbb6eecb551a')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': '1',
#  '_id': ObjectId('677c907fee4bdbb6eecb551d')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': '1',
#  '_id': ObjectId('677c907fee4bdbb6eecb551f')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': '1',
#  '_id': ObjectId('677c907fee4bdbb6eecb5520')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': '1',
#  '_id': ObjectId('677c907fee4bdbb6eecb5521')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': '1',
#  '_id': ObjectId('677c907fee4bdbb6eecb5522')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': '1',
#  '_id': ObjectId('677c907fee4bdbb6eecb5524')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': '1',
#  '_id': ObjectId('677c907fee4bdbb6eecb5535')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': '1',
#  '_id': ObjectId('677c907fee4bdbb6eecb5537')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': '1',
#  '_id': ObjectId('677c907fee4bdbb6eecb5542')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': '1',
#  '_id': ObjectId('677c907fee4bdbb6eecb5547')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': '1',
#  '_id': ObjectId('677c907fee4bdbb6eecb554b')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': '1',
#  '_id': ObjectId('677c907fee4bdbb6eecb554c')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': '1',
#  '_id': ObjectId('677c907fee4bdbb6eecb5551')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': '1',
#  '_id': ObjectId('677c907fee4bdbb6eecb5555')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': '1',
#  '_id': ObjectId('677c907fee4bdbb6eecb555c')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': '1',
#  '_id': ObjectId('677c907fee4bdbb6eecb5560')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': '1',
#  '_id': ObjectId('677c907fee4bdbb6eecb5563')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': '1',
#  '_id': ObjectId('677c907fee4bdbb6eecb5565')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': '1',
#  '_id': ObjectId('677c907fee4bdbb6eecb5567')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': '1',
#  '_id': ObjectId('677c907fee4bdbb6eecb556b')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': '1',
#  '_id': ObjectId('677c907fee4bdbb6eecb5573')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': '1',
#  '_id': ObjectId('677c907fee4bdbb6eecb5581')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': '1',
#  '_id': ObjectId('677c907fee4bdbb6eecb5588')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': '1',
#  '_id': ObjectId('677c907fee4bdbb6eecb5594')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': '1',
#  '_id': ObjectId('677c907fee4bdbb6eecb5595')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': '1',
#  '_id': ObjectId('677c907fee4bdbb6eecb5596')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': '1',
#  '_id': ObjectId('677c907fee4bdbb6eecb559b')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': '1',
#  '_id': ObjectId('677c907fee4bdbb6eecb559d')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': '1',
#  '_id': ObjectId('677c907fee4bdbb6eecb55a1')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': '1',
#  '_id': ObjectId('677c907fee4bdbb6eecb55a7')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': '1',
#  '_id': ObjectId('677c907fee4bdbb6eecb55aa')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': '1',
#  '_id': ObjectId('677c907fee4bdbb6eecb55ae')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': '1',
#  '_id': ObjectId('677c907fee4bdbb6eecb55b0')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': '1',
#  '_id': ObjectId('677c907fee4bdbb6eecb55b7')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': '1',
#  '_id': ObjectId('677c907fee4bdbb6eecb55bd')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': '1',
#  '_id': ObjectId('677c907fee4bdbb6eecb55be')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': '1',
#  '_id': ObjectId('677c907fee4bdbb6eecb55bf')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': '1',
#  '_id': ObjectId('677c907fee4bdbb6eecb55c4')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': '1',
#  '_id': ObjectId('677c907fee4bdbb6eecb55c5')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': '1',
#  '_id': ObjectId('677c907fee4bdbb6eecb55c6')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': '1',
#  '_id': ObjectId('677c907fee4bdbb6eecb55c7')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': '1',
#  '_id': ObjectId('677c907fee4bdbb6eecb55c8')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': '1',
#  '_id': ObjectId('677c907fee4bdbb6eecb55cb')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': '1',
#  '_id': ObjectId('677c907fee4bdbb6eecb55d0')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': '1',
#  '_id': ObjectId('677c907fee4bdbb6eecb55d1')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': '1',
#  '_id': ObjectId('677c907fee4bdbb6eecb55d2')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': '1',
#  '_id': ObjectId('677c907fee4bdbb6eecb55d4')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': '1',
#  '_id': ObjectId('677c907fee4bdbb6eecb55d6')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': '1',
#  '_id': ObjectId('677c907fee4bdbb6eecb55d9')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': '1',
#  '_id': ObjectId('677c907fee4bdbb6eecb55dc')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': '1',
#  '_id': ObjectId('677c907fee4bdbb6eecb55dd')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': '1',
#  '_id': ObjectId('677c907fee4bdbb6eecb55de')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': '1',
#  '_id': ObjectId('677c907fee4bdbb6eecb55df')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': '1',
#  '_id': ObjectId('677c907fee4bdbb6eecb55e0')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': '1',
#  '_id': ObjectId('677c907fee4bdbb6eecb55e1')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': '1',
#  '_id': ObjectId('677c907fee4bdbb6eecb55e2')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': '1',
#  '_id': ObjectId('677c907fee4bdbb6eecb55e4')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': '1',
#  '_id': ObjectId('677c907fee4bdbb6eecb55e9')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': '1',
#  '_id': ObjectId('677c907fee4bdbb6eecb55eb')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': '1',
#  '_id': ObjectId('677c907fee4bdbb6eecb55ef')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': '1',
#  '_id': ObjectId('677c907fee4bdbb6eecb55f2')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': '1',
#  '_id': ObjectId('677c907fee4bdbb6eecb55f5')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': '1',
#  '_id': ObjectId('677c907fee4bdbb6eecb55f7')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': '1',
#  '_id': ObjectId('677c907fee4bdbb6eecb55f9')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': '1',
#  '_id': ObjectId('677c907fee4bdbb6eecb55ff')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': '1',
#  '_id': ObjectId('677c907fee4bdbb6eecb5603')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': '1',
#  '_id': ObjectId('677c907fee4bdbb6eecb5606')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': '1',
#  '_id': ObjectId('677c907fee4bdbb6eecb5610')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': '1',
#  '_id': ObjectId('677c907fee4bdbb6eecb5615')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': '1',
#  '_id': ObjectId('677c907fee4bdbb6eecb5618')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': '1',
#  '_id': ObjectId('677c907fee4bdbb6eecb5619')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': '1',
#  '_id': ObjectId('677c907fee4bdbb6eecb561e')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': '1',
#  '_id': ObjectId('677c907fee4bdbb6eecb561f')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': '1',
#  '_id': ObjectId('677c907fee4bdbb6eecb562c')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': '1',
#  '_id': ObjectId('677c907fee4bdbb6eecb5636')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': '1',
#  '_id': ObjectId('677c907fee4bdbb6eecb5637')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': '1',
#  '_id': ObjectId('677c907fee4bdbb6eecb563e')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': '1',
#  '_id': ObjectId('677c907fee4bdbb6eecb564b')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': '1',
#  '_id': ObjectId('677c907fee4bdbb6eecb564f')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': '1',
#  '_id': ObjectId('677c907fee4bdbb6eecb5656')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': '1',
#  '_id': ObjectId('677c907fee4bdbb6eecb565a')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': '1',
#  '_id': ObjectId('677c907fee4bdbb6eecb565c')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': '1',
#  '_id': ObjectId('677c907fee4bdbb6eecb565f')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': '1',
#  '_id': ObjectId('677c907fee4bdbb6eecb5662')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': '1',
#  '_id': ObjectId('677c907fee4bdbb6eecb566d')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': '1',
#  '_id': ObjectId('677c9bdbd9e263001ccd8589')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': '',
#  '_id': ObjectId('677ca7d33d5105e6b56089d6')}

# %% [markdown]
# 3. Update the new restaurant with the `BusinessTypeID` you found.

# %%
# Update the new restaurant with the correct BusinessTypeID
update = {'$set': {'BusinessTypeID': '1'}} 
result = establishments.update_many({}, update)
pprint(result)
# Out:
# UpdateResult({'n': 38787, 'nModified': 1, 'ok': 1.0, 'updatedExisting': True}, acknowledged=True)

# %%
# Confirm that the new restaurant was updated
query = {"BusinessName":"Penang Flavours"}
for result in establishments.find(query):   
    pprint(result)
# Out:
# {'AddressLine1': 'Penang Flavours',
#  'AddressLine2': '146A Plumstead Rd',
#  'AddressLine3': 'London',
#  'AddressLine4': '',
#  'BusinessName': 'Penang Flavours',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': '1',
#  'Distance': 4623.972328074718,
#  'LocalAuthorityCode': '511',
#  'LocalAuthorityEmailAddress': 'health@royalgreenwich.gov.uk',
#  'LocalAuthorityName': 'Greenwich',
#  'LocalAuthorityWebSite': 'http://www.royalgreenwich.gov.uk',
#  'NewRatingPending': True,
#  'Phone': '',
#  'PostCode': 'SE18 7DY',
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('677c9bdbd9e263001ccd8589'),
#  'geocode': {'latitude': '51.49014200', 'longitude': '0.08384000'},
#  'scores': {'ConfidenceInManagement': '', 'Hygiene': '', 'Structural': ''}}
# {'AddressLine1': 'Penang Flavours',
#  'AddressLine2': '146A Plumstead Rd',
#  'AddressLine3': 'London',
#  'AddressLine4': '',
#  'BusinessName': 'Penang Flavours',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': '1',
#  'Distance': 4623.972328074718,
#  'LocalAuthorityCode': '511',
#  'LocalAuthorityEmailAddress': 'health@royalgreenwich.gov.uk',
#  'LocalAuthorityName': 'Greenwich',
#  'LocalAuthorityWebSite': 'http://www.royalgreenwich.gov.uk',
#  'NewRatingPending': True,
#  'Phone': '',
#  'PostCode': 'SE18 7DY',
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('677ca7d33d5105e6b56089d6'),
#  'geocode': {'latitude': '51.49014200', 'longitude': '0.08384000'},
#  'scores': {'ConfidenceInManagement': '', 'Hygiene': '', 'Structural': ''}}

# %% [markdown]
# 4. The magazine is not interested in any establishments in Dover, so check how many documents contain the Dover Local Authority. Then, remove any establishments within the Dover Local Authority from the database, and check the number of documents to ensure they were deleted.

# %%
# Find how many documents have LocalAuthorityName as "Dover"
Dover = establishments.count_documents({'LocalAuthorityName': 'Dover'})
Dover
# Out:
# 0

# %%
# Delete all documents where LocalAuthorityName is "Dover"
# Delete all the customers who have turtles
query = {'LocalAuthorityName': 'Dover'}
establishments.delete_many(query)
results = establishments.find(query)
for result in results:
    print(result)

# %%
# Check if any remaining documents include Dover
Dover = establishments.count_documents({'LocalAuthorityName': 'Dover'})
Dover
# Out:
# 0

# %%
# Check that other documents remain with 'find_one'
print(establishments.find_one())
# Out:
# {'_id': ObjectId('677c907dee4bdbb6eecabdf0'), 'FHRSID': 1043695, 'ChangesByServerID': 0, 'LocalAuthorityBusinessID': 'PI/000073616', 'BusinessName': 'The Pavilion', 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': '1', 'AddressLine1': 'East Cliff Pavilion', 'AddressLine2': 'Wear Bay Road', 'AddressLine3': 'Folkestone', 'AddressLine4': 'Kent', 'PostCode': 'CT19 6BL', 'Phone': '', 'RatingValue': '5', 'RatingKey': 'fhrs_5_en-gb', 'RatingDate': '2018-04-04T00:00:00', 'LocalAuthorityCode': '188', 'LocalAuthorityName': 'Folkestone and Hythe', 'LocalAuthorityWebSite': 'http://www.folkestone-hythe.gov.uk', 'LocalAuthorityEmailAddress': 'foodteam@folkestone-hythe.gov.uk', 'scores': {'Hygiene': 5, 'Structural': 5, 'ConfidenceInManagement': 5}, 'SchemeType': 'FHRS', 'geocode': {'longitude': '1.195625', 'latitude': '51.083812'}, 'RightToReply': '', 'Distance': 4591.765489457773, 'NewRatingPending': False, 'meta': {'dataSource': None, 'extractDate': '0001-01-01T00:00:00', 'itemCount': 0, 'returncode': None, 'totalCount': 0, 'totalPages': 0, 'pageSize': 0, 'pageNumber': 0}, 'links': [{'rel': 'self', 'href': 'https://api.ratings.food.gov.uk/establishments/1043695'}]}

# %% [markdown]
# 5. Some of the number values are stored as strings, when they should be stored as numbers.

# %% [markdown]
# Use `update_many` to convert `latitude` and `longitude` to decimal numbers.

# %%
# Change the data type from String to Decimal for longitude and latitude
update = {
    '$set': {
        'geocode.latitude': {
            '$toDouble': '$geocode.latitude' 
        },
        'geocode.longitude': {
            '$toDouble': '$geocode.longitude'
        }
    }
}
result = establishments.update_many({}, update)
pprint(result)
# Out:
# UpdateResult({'n': 38787, 'nModified': 0, 'ok': 1.0, 'updatedExisting': True}, acknowledged=True)

# %% [markdown]
# Use `update_many` to convert `RatingValue` to integer numbers.

# %%
# Set non 1-5 Rating Values to Null
non_ratings = ["AwaitingInspection", "Awaiting Inspection", "AwaitingPublication", "Pass", "Exempt"]
establishments.update_many({"RatingValue": {"$in": non_ratings}}, [ {'$set':{ "RatingValue" : None}} ])
# Out:
# UpdateResult({'n': 4091, 'nModified': 4091, 'ok': 1.0, 'updatedExisting': True}, acknowledged=True)

# %%
# Change the data type from String to Integer for RatingValue
# Query to find documents where RatingValue is a string
update = {
    '$set': {
        'RatingValue': {
            '$toInt': '$RatingValue'  # Convert RatingValue to integer
        }
    }
}
result = establishments.update_many({}, update)
pprint(result)
# Out:
# UpdateResult({'n': 38787, 'nModified': 38787, 'ok': 1.0, 'updatedExisting': True}, acknowledged=True)

# %%
# Check that the coordinates and rating value are now numbers
pprint(establishments.find_one())
# Out:
# {'AddressLine1': 'East Cliff Pavilion',
#  'AddressLine2': 'Wear Bay Road',
#  'AddressLine3': 'Folkestone',
#  'AddressLine4': 'Kent',
#  'BusinessName': 'The Pavilion',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': '1',
#  'ChangesByServerID': 0,
#  'Distance': 4591.765489457773,
#  'FHRSID': 1043695,
#  'LocalAuthorityBusinessID': 'PI/000073616',
#  'LocalAuthorityCode': '188',
#  'LocalAuthorityEmailAddress': 'foodteam@folkestone-hythe.gov.uk',
#  'LocalAuthorityName': 'Folkestone and Hythe',
#  'LocalAuthorityWebSite': 'http://www.folkestone-hythe.gov.uk',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'CT19 6BL',
#  'RatingDate': '2018-04-04T00:00:00',
#  'RatingKey': 'fhrs_5_en-gb',
#  'RatingValue': {'$toInt': '$RatingValue'},
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('677c907dee4bdbb6eecabdf0'),
#  'geocode': {'latitude': {'$toDouble': '$geocode.latitude'},
#              'longitude': {'$toDouble': '$geocode.longitude'}},
#  'links': [{'href': 'https://api.ratings.food.gov.uk/establishments/1043695',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 5, 'Hygiene': 5, 'Structural': 5}}
